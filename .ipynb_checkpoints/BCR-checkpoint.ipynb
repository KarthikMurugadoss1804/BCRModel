# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
data = pd.read_excel("BCR_New.xlsx", sheet_name="BCR Sheet", index_col=0, header=0)
data.head()
# Out:
#            Date_of_Brachytherapy_f1  Current Meds  Cigarette Smoker  Zubrod  \
# internalid
# 2048356C                 2013-05-02             2                 2       0
# F3F1F587                 2015-06-10             2                 2       0
# 922303E                  2011-11-17             2                 2       9
# 883F5E4E                 2015-02-27             2                 2       0
# 9DF41142                 2015-02-13             2                 2       0
#
#             DRE  Prior Cancer  Total Core Biopsies  Type of biopsy  \
# internalid
# 2048356C      0             1                    6               1
# F3F1F587      0             1                   14               1
# 922303E       2             2                   10               1
# 883F5E4E      0             1                   13               1
# 9DF41142      0             1                   14               1
#
#             Pos Biopsies  Percent Pos Biopsies  ...  Brachytherapy_Centre  \
# internalid                                      ...
# 2048356C               3                 50.00  ...                     1
# F3F1F587               1                  7.14  ...                     1
# 922303E                1                 10.00  ...                     1
# 883F5E4E               2                 15.38  ...                     1
# 9DF41142               1                  7.14  ...                     1
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies  Risk_Status  \
# internalid
# 2048356C     66              2                            50            2
# F3F1F587     64              1                             7            1
# 922303E      76              2                            10            2
# 883F5E4E     62              1                            15            1
# 9DF41142     62              1                             7            1
#
#             Status_of_this_Visit  BCR      BCR_Time_Months  BCR_Time_Year  \
# internalid
# 2048356C                       1   No  9223372036854769664              5
# F3F1F587                       1   No  9223372036854769664              4
# 922303E                        1   No  9223372036854769664              6
# 883F5E4E                       1   No  9223372036854769664              0
# 9DF41142                       1   No  9223372036854769664              5
#
#             BCR_Binned
# internalid
# 2048356C             5
# F3F1F587             5
# 922303E             10
# 883F5E4E             5
# 9DF41142             5
#
# [5 rows x 36 columns]

# %%
set(data.loc[data["BCR"]=="No"]["BCR_Time_Months"])
# Out:
# {9223372036854769664}

# %%
mask = data.BCR_Time_Months > 20000
data.loc[mask, "BCR_Binned"] = -1

# %%
data.columns
# Out:
# Index(['Date_of_Brachytherapy_f1', 'Current Meds', 'Cigarette Smoker',
#        'Zubrod', 'DRE', 'Prior Cancer', 'Total Core Biopsies',
#        'Type of biopsy', 'Pos Biopsies', 'Percent Pos Biopsies',
#        'Primary Score - Gleason', 'Secondary Score - Gleason',
#        'Gleason Score overall', 'Perineural Invasion', 'Baseline PSA Value',
#        'Tumor Palpable', 'Seminal Vesicle Invasion', 'T Stage', 'N Stage',
#        'M Stage', 'CT Abdomen/Pelvis', 'MRI Abdomen/Pelvis',
#        'D'Amico Risk Category', 'Bone Scan', 'Treatment',
#        'Brachytherapy_Total_Dose_Received', 'Brachytherapy_Centre', 'Age',
#        'Gleason_Grade', 'Percentage_Positive_Biopsies', 'Risk_Status',
#        'Status_of_this_Visit', 'BCR', 'BCR_Time_Months', 'BCR_Time_Year',
#        'BCR_Binned'],
#       dtype='object')

# %%
set(data["DRE"])
# Out:
# {0, 1, 2}

# %%
data["Baseline PSA Value"] =  np.log2(data["Baseline PSA Value"].values)

# %%
data["BCR"] = data["BCR"].replace({"Yes": 1, "No": 0})
data
# Out:
#            Date_of_Brachytherapy_f1  Current Meds  Cigarette Smoker  Zubrod  \
# internalid
# 2048356C                 2013-05-02             2                 2       0
# F3F1F587                 2015-06-10             2                 2       0
# 922303E                  2011-11-17             2                 2       9
# 883F5E4E                 2015-02-27             2                 2       0
# 9DF41142                 2015-02-13             2                 2       0
# ...                             ...           ...               ...     ...
# 65ED7615                 2015-03-13             1                 1       0
# DE21A6C5                 2016-10-28             1                 1       0
# 6226C1A0                 2018-10-12             1                 1       0
# 26A34410                 2018-02-23             1                 1       0
# D4A003A7                 2018-11-16             1                 1       0
#
#             DRE  Prior Cancer  Total Core Biopsies  Type of biopsy  \
# internalid
# 2048356C      0             1                    6               1
# F3F1F587      0             1                   14               1
# 922303E       2             2                   10               1
# 883F5E4E      0             1                   13               1
# 9DF41142      0             1                   14               1
# ...         ...           ...                  ...             ...
# 65ED7615      0             0                   15               1
# DE21A6C5      0             1                   16               1
# 6226C1A0      0             1                   14               1
# 26A34410      0             1                   14               1
# D4A003A7      0             1                   15               1
#
#             Pos Biopsies  Percent Pos Biopsies  ...  Brachytherapy_Centre  \
# internalid                                      ...
# 2048356C               3                 50.00  ...                     1
# F3F1F587               1                  7.14  ...                     1
# 922303E                1                 10.00  ...                     1
# 883F5E4E               2                 15.38  ...                     1
# 9DF41142               1                  7.14  ...                     1
# ...                  ...                   ...  ...                   ...
# 65ED7615               1                  6.67  ...                     1
# DE21A6C5               3                 18.75  ...                     1
# 6226C1A0               5                 35.71  ...                     1
# 26A34410               8                 57.14  ...                     1
# D4A003A7              12                 80.00  ...                     1
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies  Risk_Status  \
# internalid
# 2048356C     66              2                            50            2
# F3F1F587     64              1                             7            1
# 922303E      76              2                            10            2
# 883F5E4E     62              1                            15            1
# 9DF41142     62              1                             7            1
# ...         ...            ...                           ...          ...
# 65ED7615     69              4                             6            3
# DE21A6C5     77              1                            18            1
# 6226C1A0     71              2                            35            2
# 26A34410     73              2                            57            2
# D4A003A7     73              5                            80            3
#
#             Status_of_this_Visit  BCR      BCR_Time_Months  BCR_Time_Year  \
# internalid
# 2048356C                       1    0  9223372036854769664              5
# F3F1F587                       1    0  9223372036854769664              4
# 922303E                        1    0  9223372036854769664              6
# 883F5E4E                       1    0  9223372036854769664              0
# 9DF41142                       1    0  9223372036854769664              5
# ...                          ...  ...                  ...            ...
# 65ED7615                       1    0  9223372036854769664              5
# DE21A6C5                       1    0  9223372036854769664              3
# 6226C1A0                       1    0  9223372036854769664              2
# 26A34410                       1    0  9223372036854769664              3
# D4A003A7                       4    1                   19              1
#
#             BCR_Binned
# internalid
# 2048356C            -1
# F3F1F587            -1
# 922303E             -1
# 883F5E4E            -1
# 9DF41142            -1
# ...                ...
# 65ED7615            -1
# DE21A6C5            -1
# 6226C1A0            -1
# 26A34410            -1
# D4A003A7             5
#
# [926 rows x 36 columns]

# %%
data.dtypes
# Out:
# Date_of_Brachytherapy_f1             datetime64[ns]
# Current Meds                                  int64
# Cigarette Smoker                              int64
# Zubrod                                        int64
# DRE                                           int64
# Prior Cancer                                  int64
# Total Core Biopsies                           int64
# Type of biopsy                                int64
# Pos Biopsies                                  int64
# Percent Pos Biopsies                        float64
# Primary Score - Gleason                       int64
# Secondary Score - Gleason                     int64
# Gleason Score overall                         int64
# Perineural Invasion                           int64
# Baseline PSA Value                          float64
# Tumor Palpable                                int64
# Seminal Vesicle Invasion                      int64
# T Stage                                       int64
# N Stage                                       int64
# M Stage                                       int64
# CT Abdomen/Pelvis                             int64
# MRI Abdomen/Pelvis                            int64
# D'Amico Risk Category                         int64
# Bone Scan                                     int64
# Treatment                                     int64
# Brachytherapy_Total_Dose_Received             int64
# Brachytherapy_Centre                          int64
# Age                                           int64
# Gleason_Grade                                 int64
# Percentage_Positive_Biopsies                  int64
# Risk_Status                                   int64
# Status_of_this_Visit                          int64
# BCR                                           int64
# BCR_Time_Months                               int64
# BCR_Time_Year                                 int64
# BCR_Binned                                    int64
# dtype: object

# %%
data["Date_of_Brachytherapy_f1"].groupby(data["Date_of_Brachytherapy_f1"].dt.year).count().plot(kind="bar", figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='Date_of_Brachytherapy_f1'>

# %%
#filtering out data until Dec 2014
trunc_data = data.loc[data["Date_of_Brachytherapy_f1"] <"2015-01-01"]
trunc_data
# Out:
#            Date_of_Brachytherapy_f1  Current Meds  Cigarette Smoker  Zubrod  \
# internalid
# 2048356C                 2013-05-02             2                 2       0
# 922303E                  2011-11-17             2                 2       9
# 37915CB3                 2010-12-08             2                 2       0
# 21D65521                 2011-04-21             2                 2       0
# 10B41FFA                 2009-12-17             2                 2       0
# ...                             ...           ...               ...     ...
# 494EFD93                 2014-12-04             1                 1       0
# 34EE9A26                 2010-07-30             1                 1       0
# FD30A02                  2010-05-12             1                 1       0
# 23DF6DA2                 2008-11-26             1                 1       0
# 38B766BD                 2009-07-22             1                 1       0
#
#             DRE  Prior Cancer  Total Core Biopsies  Type of biopsy  \
# internalid
# 2048356C      0             1                    6               1
# 922303E       2             2                   10               1
# 37915CB3      0             1                   12               1
# 21D65521      1             1                   14               1
# 10B41FFA      0             1                    6               1
# ...         ...           ...                  ...             ...
# 494EFD93      0             1                   14               1
# 34EE9A26      2             1                   10               1
# FD30A02       1             1                   18               1
# 23DF6DA2      1             1                    6               1
# 38B766BD      0             1                    6               1
#
#             Pos Biopsies  Percent Pos Biopsies  ...  Brachytherapy_Centre  \
# internalid                                      ...
# 2048356C               3                 50.00  ...                     1
# 922303E                1                 10.00  ...                     1
# 37915CB3               1                  8.33  ...                     1
# 21D65521               6                 42.86  ...                     1
# 10B41FFA               3                 50.00  ...                     1
# ...                  ...                   ...  ...                   ...
# 494EFD93               3                 21.43  ...                     1
# 34EE9A26               3                 30.00  ...                     1
# FD30A02                4                 22.22  ...                     1
# 23DF6DA2               1                 16.67  ...                     1
# 38B766BD               1                 16.67  ...                     1
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies  Risk_Status  \
# internalid
# 2048356C     66              2                            50            2
# 922303E      76              2                            10            2
# 37915CB3     60              1                             8            1
# 21D65521     63              3                            42            2
# 10B41FFA     53              1                            50            1
# ...         ...            ...                           ...          ...
# 494EFD93     66              2                            21            2
# 34EE9A26     63              3                            30            2
# FD30A02      68              4                            22            3
# 23DF6DA2     62              1                            16            1
# 38B766BD     65              1                            16            1
#
#             Status_of_this_Visit  BCR      BCR_Time_Months  BCR_Time_Year  \
# internalid
# 2048356C                       1    0  9223372036854769664              5
# 922303E                        1    0  9223372036854769664              6
# 37915CB3                       1    0  9223372036854769664              3
# 21D65521                       4    1                   80              6
# 10B41FFA                       1    0  9223372036854769664              4
# ...                          ...  ...                  ...            ...
# 494EFD93                       1    0  9223372036854769664              0
# 34EE9A26                       1    0  9223372036854769664              5
# FD30A02                        5    1                   71              5
# 23DF6DA2                       1    0  9223372036854769664              4
# 38B766BD                       1    0  9223372036854769664              6
#
#             BCR_Binned
# internalid
# 2048356C            -1
# 922303E             -1
# 37915CB3            -1
# 21D65521            10
# 10B41FFA            -1
# ...                ...
# 494EFD93            -1
# 34EE9A26            -1
# FD30A02              5
# 23DF6DA2            -1
# 38B766BD            -1
#
# [693 rows x 36 columns]

# %% [markdown]
# # Execution

# %%
from imblearn.combine import SMOTEENN
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import joblib


from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

# %%
#list of informative features

cols = [
    "Current Meds", "Prior Cancer", "Total Core Biopsies", "Pos Biopsies",
    "Percent Pos Biopsies", "Gleason Score overall", "Perineural Invasion",
    "Baseline PSA Value", "T Stage", "D'Amico Risk Category", "Treatment",
    "Age", "Gleason_Grade", "Percentage_Positive_Biopsies"
]

# %%
X = trunc_data[cols]
y = trunc_data["BCR_Binned"].values #the target
X
# Out:
#             Current Meds  Prior Cancer  Total Core Biopsies  Pos Biopsies  \
# internalid
# 2048356C               2             1                    6             3
# 922303E                2             2                   10             1
# 37915CB3               2             1                   12             1
# 21D65521               2             1                   14             6
# 10B41FFA               2             1                    6             3
# ...                  ...           ...                  ...           ...
# 494EFD93               1             1                   14             3
# 34EE9A26               1             1                   10             3
# FD30A02                1             1                   18             4
# 23DF6DA2               1             1                    6             1
# 38B766BD               1             1                    6             1
#
#             Percent Pos Biopsies  Gleason Score overall  Perineural Invasion  \
# internalid
# 2048356C                   50.00                      7                    2
# 922303E                    10.00                      7                    3
# 37915CB3                    8.33                      6                    2
# 21D65521                   42.86                      7                    1
# 10B41FFA                   50.00                      6                    2
# ...                          ...                    ...                  ...
# 494EFD93                   21.43                      7                    2
# 34EE9A26                   30.00                      7                    1
# FD30A02                    22.22                      8                    2
# 23DF6DA2                   16.67                      6                    2
# 38B766BD                   16.67                      6                    2
#
#             Baseline PSA Value  T Stage  D'Amico Risk Category  Treatment  \
# internalid
# 2048356C              2.321928        2                      2          1
# 922303E               2.847997        1                      2          2
# 37915CB3              2.400538        1                      1          2
# 21D65521              2.324811        1                      2          4
# 10B41FFA              2.263034        1                      1          1
# ...                        ...      ...                    ...        ...
# 494EFD93              6.209453        1                      2          2
# 34EE9A26              3.446256        2                      2          4
# FD30A02               3.169925        1                      3          4
# 23DF6DA2              2.321928        1                      1          1
# 38B766BD              3.035624        1                      1          1
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies
# internalid
# 2048356C     66              2                            50
# 922303E      76              2                            10
# 37915CB3     60              1                             8
# 21D65521     63              3                            42
# 10B41FFA     53              1                            50
# ...         ...            ...                           ...
# 494EFD93     66              2                            21
# 34EE9A26     63              3                            30
# FD30A02      68              4                            22
# 23DF6DA2     62              1                            16
# 38B766BD     65              1                            16
#
# [693 rows x 14 columns]

# %% [markdown]
# ## Resampling using SMOTEENN

# %%
smote_enn = SMOTEENN(random_state=1992)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

#splitting into train and test
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.33, shuffle=True, random_state=1992)

# %% [markdown]
# ## Model execution

# %%
#the following are the best parameter settings given by RandomisedSearchCV of a wider parameter grid (around 25000 combinations were tested)

best_params = {'n_estimators': 1860,
 'min_samples_split': 2,
 'min_samples_leaf': 2,
 'max_features': 'auto',
 'max_depth': 90,
 'criterion': 'entropy',
 'bootstrap': False}

# %%
#setting the pipeline for the model: Standardscaler and then RandomForestClassifier -- train it then
rfc = Pipeline(steps=[('scaler', StandardScaler()), ('rf', RandomForestClassifier(random_state=1992, n_jobs=-1, **best_params))]).fit(X_train,y_train)

# %%
y_pred = rfc.predict(X_test) #prediction task

# %%
f1_score(y_test, y_pred, average="weighted") #evaluation
# Out:
# 0.9688808913510522

# %% [markdown]
# ## Sanity check over data from 2015

# %%
ho_data = data.loc[data["Date_of_Brachytherapy_f1"] >="2015-01-01"]
ho_data
# Out:
#            Date_of_Brachytherapy_f1  Current Meds  Cigarette Smoker  Zubrod  \
# internalid
# F3F1F587                 2015-06-10             2                 2       0
# 883F5E4E                 2015-02-27             2                 2       0
# 9DF41142                 2015-02-13             2                 2       0
# 16C69902                 2018-05-18             2                 2       0
# B65BEA3E                 2019-04-12             2                 2       0
# ...                             ...           ...               ...     ...
# 65ED7615                 2015-03-13             1                 1       0
# DE21A6C5                 2016-10-28             1                 1       0
# 6226C1A0                 2018-10-12             1                 1       0
# 26A34410                 2018-02-23             1                 1       0
# D4A003A7                 2018-11-16             1                 1       0
#
#             DRE  Prior Cancer  Total Core Biopsies  Type of biopsy  \
# internalid
# F3F1F587      0             1                   14               1
# 883F5E4E      0             1                   13               1
# 9DF41142      0             1                   14               1
# 16C69902      2             1                   14               1
# B65BEA3E      0             1                   12               1
# ...         ...           ...                  ...             ...
# 65ED7615      0             0                   15               1
# DE21A6C5      0             1                   16               1
# 6226C1A0      0             1                   14               1
# 26A34410      0             1                   14               1
# D4A003A7      0             1                   15               1
#
#             Pos Biopsies  Percent Pos Biopsies  ...  Brachytherapy_Centre  \
# internalid                                      ...
# F3F1F587               1                  7.14  ...                     1
# 883F5E4E               2                 15.38  ...                     1
# 9DF41142               1                  7.14  ...                     1
# 16C69902               2                 14.29  ...                     1
# B65BEA3E               5                 41.67  ...                     1
# ...                  ...                   ...  ...                   ...
# 65ED7615               1                  6.67  ...                     1
# DE21A6C5               3                 18.75  ...                     1
# 6226C1A0               5                 35.71  ...                     1
# 26A34410               8                 57.14  ...                     1
# D4A003A7              12                 80.00  ...                     1
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies  Risk_Status  \
# internalid
# F3F1F587     64              1                             7            1
# 883F5E4E     62              1                            15            1
# 9DF41142     62              1                             7            1
# 16C69902     71              2                            14            2
# B65BEA3E     49              1                            41            1
# ...         ...            ...                           ...          ...
# 65ED7615     69              4                             6            3
# DE21A6C5     77              1                            18            1
# 6226C1A0     71              2                            35            2
# 26A34410     73              2                            57            2
# D4A003A7     73              5                            80            3
#
#             Status_of_this_Visit  BCR      BCR_Time_Months  BCR_Time_Year  \
# internalid
# F3F1F587                       1    0  9223372036854769664              4
# 883F5E4E                       1    0  9223372036854769664              0
# 9DF41142                       1    0  9223372036854769664              5
# 16C69902                       1    0  9223372036854769664              0
# B65BEA3E                       1    0  9223372036854769664              0
# ...                          ...  ...                  ...            ...
# 65ED7615                       1    0  9223372036854769664              5
# DE21A6C5                       1    0  9223372036854769664              3
# 6226C1A0                       1    0  9223372036854769664              2
# 26A34410                       1    0  9223372036854769664              3
# D4A003A7                       4    1                   19              1
#
#             BCR_Binned
# internalid
# F3F1F587            -1
# 883F5E4E            -1
# 9DF41142            -1
# 16C69902            -1
# B65BEA3E            -1
# ...                ...
# 65ED7615            -1
# DE21A6C5            -1
# 6226C1A0            -1
# 26A34410            -1
# D4A003A7             5
#
# [233 rows x 36 columns]

# %%
X_ho = ho_data[cols]
y_ho = ho_data["BCR_Binned"].values
X_ho
# Out:
#             Current Meds  Prior Cancer  Total Core Biopsies  Pos Biopsies  \
# internalid
# F3F1F587               2             1                   14             1
# 883F5E4E               2             1                   13             2
# 9DF41142               2             1                   14             1
# 16C69902               2             1                   14             2
# B65BEA3E               2             1                   12             5
# ...                  ...           ...                  ...           ...
# 65ED7615               1             0                   15             1
# DE21A6C5               1             1                   16             3
# 6226C1A0               1             1                   14             5
# 26A34410               1             1                   14             8
# D4A003A7               1             1                   15            12
#
#             Percent Pos Biopsies  Gleason Score overall  Perineural Invasion  \
# internalid
# F3F1F587                    7.14                      6                    3
# 883F5E4E                   15.38                      6                    2
# 9DF41142                    7.14                      6                    2
# 16C69902                   14.29                      7                    3
# B65BEA3E                   41.67                      6                    1
# ...                          ...                    ...                  ...
# 65ED7615                    6.67                      8                    2
# DE21A6C5                   18.75                      6                    2
# 6226C1A0                   35.71                      7                    3
# 26A34410                   57.14                      7                    1
# D4A003A7                   80.00                      9                    1
#
#             Baseline PSA Value  T Stage  D'Amico Risk Category  Treatment  \
# internalid
# F3F1F587              2.232661        4                      1          2
# 883F5E4E              2.827819        1                      1          1
# 9DF41142              2.459432        4                      1          2
# 16C69902              3.053111        4                      2          1
# B65BEA3E              2.000000        1                      1          1
# ...                        ...      ...                    ...        ...
# 65ED7615              3.169925        4                      3          4
# DE21A6C5              3.446256        2                      1          1
# 6226C1A0              2.906891        1                      2          3
# 26A34410              2.560715        2                      2          1
# D4A003A7              2.944858        2                      3          4
#
#             Age  Gleason_Grade  Percentage_Positive_Biopsies
# internalid
# F3F1F587     64              1                             7
# 883F5E4E     62              1                            15
# 9DF41142     62              1                             7
# 16C69902     71              2                            14
# B65BEA3E     49              1                            41
# ...         ...            ...                           ...
# 65ED7615     69              4                             6
# DE21A6C5     77              1                            18
# 6226C1A0     71              2                            35
# 26A34410     73              2                            57
# D4A003A7     73              5                            80
#
# [233 rows x 14 columns]

# %%
y_pred = rfc.predict(X_ho)
f1_score(y_ho, y_pred, average="weighted")
# Out:
# 0.8407178321972564
